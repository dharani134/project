# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://www.elections.in/andhra-pradesh/list-of-chief-ministers.html"

# %%
page=requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>List of Chief Ministers of Andhra Pradesh</title>
# <meta content="List of Chief Ministers of Andhra Pradesh with current Chief Minister of Andhra Pradesh. Know all the details of Cheif Ministers of Andhra Pradesh" name="description"/>
# <meta content="list of cm in andhra pradesh, andhra pradesh cm list, cheif ministers of andhra pradesh, andhra pradesh cheif minister list, current chief minister of andhra pradesh, chief minister of andhra pradesh" name="keywords"/>
# <!-- <link rel="amphtml" href="https://www.elections.in/amp/andhra-pradesh/list-of-chief-ministers.html"> -->
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="hi" http-equiv="Content-Language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="tableizer-table">
# <thead><tr class="tableizer-firstrow"><th>S. No.</th><th>Name of CM</th><th>From</th><th>To</th><th>Party</th></tr></thead><tbody>
# <tr><td>1</td><td>Y. S. Jaganmohan Reddy</td><td>30-May-19</td><td>Incumbent</td><td>YSR Congress Party</td></tr>
# <tr><td>2</td><td>Chandrababu Naidu</td><td>02-Jun-14</td><td>29-May-19</td><td>TDP</td></tr>
# <tr><td>3</td><td>President's Rule</td><td>01-Mar-14</td><td>02-Jun-14</td><td> </td></tr>
# <tr><td>4</td><td>Sri. N.Kiran Kumar Reddy</td><td>25-Nov-10</td><td>01-Mar-14</td><td>INC</td></tr>
# <tr><td>5</td><td>Sri. K. Rosaiah</td><td>09-Apr-09</td><td>24-Nov-10</td><td>INC</td></tr>
# <tr><td>6</td><td>Dr.Y.S. Rajasekhara Reddy</td><td>14-Apr-04</td><td>09-Feb-09</td><td>INC</td></tr>
# <tr><td>7</td><td>Sri N. Chandra Babu Naidu</td><td>09-Jan-95</td><td>14-Apr-04</td><td>TDP</td></tr>
# <tr><td>8</td><td>Sri N.T.Rama Rao</td><td>12-Dec-94</td><td>09-Jan-95</td><td>TDP</td></tr>
# ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th>S. No.</th>, <th>Name of CM</th>, <th>From</th>, <th>To</th>, <th>Party</th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['S. No.', 'Name of CM', 'From', 'To', 'Party']

# %%
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [S. No., Name of CM, From, To, Party]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
# Out:
# [<tr class="tableizer-firstrow"><th>S. No.</th><th>Name of CM</th><th>From</th><th>To</th><th>Party</th></tr>, <tr><td>1</td><td>Y. S. Jaganmohan Reddy</td><td>30-May-19</td><td>Incumbent</td><td>YSR Congress Party</td></tr>, <tr><td>2</td><td>Chandrababu Naidu</td><td>02-Jun-14</td><td>29-May-19</td><td>TDP</td></tr>, <tr><td>3</td><td>President's Rule</td><td>01-Mar-14</td><td>02-Jun-14</td><td> </td></tr>, <tr><td>4</td><td>Sri. N.Kiran Kumar Reddy</td><td>25-Nov-10</td><td>01-Mar-14</td><td>INC</td></tr>, <tr><td>5</td><td>Sri. K. Rosaiah</td><td>09-Apr-09</td><td>24-Nov-10</td><td>INC</td></tr>, <tr><td>6</td><td>Dr.Y.S. Rajasekhara Reddy</td><td>14-Apr-04</td><td>09-Feb-09</td><td>INC</td></tr>, <tr><td>7</td><td>Sri N. Chandra Babu Naidu</td><td>09-Jan-95</td><td>14-Apr-04</td><td>TDP</td></tr>, <tr><td>8</td><td>Sri N.T.Rama Rao</td><td>12-Dec-94</td><td>09-Jan-95</td><td>TDP</td></tr>, <tr><td>9</td><td>Sri K.VijayaBhaskara Reddy</td><td>10-Sep-92</td><td>12-Dec-94</td><td>I
# ...

# %%
ind=0
for i in rows[1:6]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['1', 'Y. S. Jaganmohan Reddy', '30-May-19', 'Incumbent', 'YSR Congress Party']
# ['2', 'Chandrababu Naidu', '02-Jun-14', '29-May-19', 'TDP']
# ['3', "President's Rule", '01-Mar-14', '02-Jun-14', '\xa0']
# ['4', 'Sri. N.Kiran Kumar Reddy', '25-Nov-10', '01-Mar-14', 'INC']
# ['5', 'Sri. K. Rosaiah', '09-Apr-09', '24-Nov-10', 'INC']

# %%
df
# Out:
#   S. No.                Name of CM       From         To               Party
# 0      1    Y. S. Jaganmohan Reddy  30-May-19  Incumbent  YSR Congress Party
# 1      2         Chandrababu Naidu  02-Jun-14  29-May-19                 TDP
# 2      3          President's Rule  01-Mar-14  02-Jun-14
# 3      4  Sri. N.Kiran Kumar Reddy  25-Nov-10  01-Mar-14                 INC
# 4      5           Sri. K. Rosaiah  09-Apr-09  24-Nov-10                 INC

# %%
df.to_csv("list of chief ministers of andharpradesh.csv")

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.elections.in/andhra-pradesh/list-of-chief-ministers.html"

# %%
p = requests.get(url)

# %%
code = BeautifulSoup(p.text,'html')

# %%
t = code.find('table')
print(t)
# Out:
# <table class="tableizer-table">
# <thead><tr class="tableizer-firstrow"><th>S. No.</th><th>Name of CM</th><th>From</th><th>To</th><th>Party</th></tr></thead><tbody>
# <tr><td>1</td><td>Y. S. Jaganmohan Reddy</td><td>30-May-19</td><td>Incumbent</td><td>YSR Congress Party</td></tr>
# <tr><td>2</td><td>Chandrababu Naidu</td><td>02-Jun-14</td><td>29-May-19</td><td>TDP</td></tr>
# <tr><td>3</td><td>President's Rule</td><td>01-Mar-14</td><td>02-Jun-14</td><td> </td></tr>
# <tr><td>4</td><td>Sri. N.Kiran Kumar Reddy</td><td>25-Nov-10</td><td>01-Mar-14</td><td>INC</td></tr>
# <tr><td>5</td><td>Sri. K. Rosaiah</td><td>09-Apr-09</td><td>24-Nov-10</td><td>INC</td></tr>
# <tr><td>6</td><td>Dr.Y.S. Rajasekhara Reddy</td><td>14-Apr-04</td><td>09-Feb-09</td><td>INC</td></tr>
# <tr><td>7</td><td>Sri N. Chandra Babu Naidu</td><td>09-Jan-95</td><td>14-Apr-04</td><td>TDP</td></tr>
# <tr><td>8</td><td>Sri N.T.Rama Rao</td><td>12-Dec-94</td><td>09-Jan-95</td><td>TDP</td></tr>
# ...

# %%
data = t.find_all('td')
print(data)
# Out:
# [<td>1</td>, <td>Y. S. Jaganmohan Reddy</td>, <td>30-May-19</td>, <td>Incumbent</td>, <td>YSR Congress Party</td>, <td>2</td>, <td>Chandrababu Naidu</td>, <td>02-Jun-14</td>, <td>29-May-19</td>, <td>TDP</td>, <td>3</td>, <td>President's Rule</td>, <td>01-Mar-14</td>, <td>02-Jun-14</td>, <td> </td>, <td>4</td>, <td>Sri. N.Kiran Kumar Reddy</td>, <td>25-Nov-10</td>, <td>01-Mar-14</td>, <td>INC</td>, <td>5</td>, <td>Sri. K. Rosaiah</td>, <td>09-Apr-09</td>, <td>24-Nov-10</td>, <td>INC</td>, <td>6</td>, <td>Dr.Y.S. Rajasekhara Reddy</td>, <td>14-Apr-04</td>, <td>09-Feb-09</td>, <td>INC</td>, <td>7</td>, <td>Sri N. Chandra Babu Naidu</td>, <td>09-Jan-95</td>, <td>14-Apr-04</td>, <td>TDP</td>, <td>8</td>, <td>Sri N.T.Rama Rao</td>, <td>12-Dec-94</td>, <td>09-Jan-95</td>, <td>TDP</td>, <td>9</td>, <td>Sri K.VijayaBhaskara Reddy</td>, <td>10-Sep-92</td>, <td>12-Dec-94</td>, <td>INC</td>, <td>10</td>, <td>Sri N.Janardhana Reddy</td>, <td>17-Dec-90</td>, <td>10-Sep-92</td>, <td>INC</td>, <td>1
# ...

# %%
data_act = [i.text for i in data]

# %%
print(data_act)
# Out:
# ['1', 'Y. S. Jaganmohan Reddy', '30-May-19', 'Incumbent', 'YSR Congress Party', '2', 'Chandrababu Naidu', '02-Jun-14', '29-May-19', 'TDP', '3', "President's Rule", '01-Mar-14', '02-Jun-14', '\xa0', '4', 'Sri. N.Kiran Kumar Reddy', '25-Nov-10', '01-Mar-14', 'INC', '5', 'Sri. K. Rosaiah', '09-Apr-09', '24-Nov-10', 'INC', '6', 'Dr.Y.S. Rajasekhara Reddy', '14-Apr-04', '09-Feb-09', 'INC', '7', 'Sri N. Chandra Babu Naidu', '09-Jan-95', '14-Apr-04', 'TDP', '8', 'Sri N.T.Rama Rao', '12-Dec-94', '09-Jan-95', 'TDP', '9', 'Sri K.VijayaBhaskara Reddy', '10-Sep-92', '12-Dec-94', 'INC', '10', 'Sri N.Janardhana Reddy', '17-Dec-90', '10-Sep-92', 'INC', '11', 'Dr.Marri Chenna Reddy', '12-Mar-89', '17-Dec-90', 'INC', '12', 'Sri N.T.Rama Rao', '03-Sep-85', '12-Mar-89', 'TDP', '13', 'Sri N.T.Rama Rao', '16-Sep-84', '03-Sep-85', 'INC', '14', 'Sri N.Bhaskara rao', '16-Aug-84', '16-Sep-84', 'TDP', '15', 'Sri N.T.Rama Rao', '01-Sep-83', '16-Aug-84', 'INC', '16', 'Sri Bhavanam Venkataram', '24-Feb-82', '20-
# ...

# %%
newdf= pd.DataFrame(columns = ['Name of CM','From','To','Party'])

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [Name of CM, From, To, Party]
# Index: []

# %%
data_act[0:4]
print(len(data_act))
# Out:
# 140

# %%
ind = 0
st = 0
stop = 4
for i in data_act:
  if stop <= 40:
    newdf.loc[ind]= data_act[st:stop]
    st = st+4
    stop = stop+4
    ind = ind+1

# %%
newdf
# Out:
#                  Name of CM                    From  \
# 0                         1  Y. S. Jaganmohan Reddy
# 1        YSR Congress Party                       2
# 2                 29-May-19                     TDP
# 3                 01-Mar-14               02-Jun-14
# 4  Sri. N.Kiran Kumar Reddy               25-Nov-10
# 5                         5         Sri. K. Rosaiah
# 6                       INC                       6
# 7                 09-Feb-09                     INC
# 8                 09-Jan-95               14-Apr-04
# 9          Sri N.T.Rama Rao               12-Dec-94
#
#                           To                      Party
# 0                  30-May-19                  Incumbent
# 1          Chandrababu Naidu                  02-Jun-14
# 2                          3           President's Rule
# 3                                                     4
# 4                  01-Mar-14                        INC
# ...
